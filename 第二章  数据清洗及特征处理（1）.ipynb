# %%
# 先导入数据和库
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 一、数据清洗简述
# ####  我们拿到的数据通常是不干净的，所谓的不干净，就是数据中有缺失值，有一些异常点等，需要经过一定的处理才能继续做后面的分析或建模，所以拿到数据的第一步是进行数据清洗，本章我们将学习缺失值、重复值、字符串和数据转换等操作，将数据清洗成可以分析或建模的样子。

# %% [markdown]
# ### 1.1 缺失值观察与处理
# #### 我们拿到的数据经常会有很多缺失值，比如我们可以看到Cabin列存在NaN，那其他列还有没有缺失值，这些缺失值要怎么处理呢

# %% [markdown]
# #### 1.1.1 缺失值观察
# ##### (1) 请查看每个特征缺失值个数
# ##### (2) 请查看Age， Cabin， Embarked列的数据

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().head()  #判断是否有缺失值  True 则为 缺失值
# Out:
#    PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0        False     False   False  False  False  False  False  False   False
# 1        False     False   False  False  False  False  False  False   False
# 2        False     False   False  False  False  False  False  False   False
# 3        False     False   False  False  False  False  False  False   False
# 4        False     False   False  False  False  False  False  False   False
#
#     Fare  Cabin  Embarked
# 0  False   True     False
# 1  False  False     False
# 2  False   True     False
# 3  False  False     False
# 4  False   True     False

# %%
df.isnull().sum()   # 统计缺失值的个数
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# 结合 any（） 来判断某列是否有缺失值  默认 axis = 0  某列   any() 若有一个 缺失值 NaN 则返回 True
df.isnull().any()    # 可与  df.info()  df.isnull().sum() 共同观察
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.isnull().any(axis = 1)  # 判断某行是否有缺失值， 猜测使用较少
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Length: 891, dtype: bool

# %%
df.isnull().values.any()
# Out:
# True

# %%
# 2）查看Age， Cabin， Embarked列的数据
df[['Age','Cabin','Embarked']].head()
# Out:
#     Age Cabin Embarked
# 0  22.0   NaN        S
# 1  38.0   C85        C
# 2  26.0   NaN        S
# 3  35.0  C123        S
# 4  35.0   NaN        S

# %% [markdown]
# #### 1.1.2 对缺失值进行处理   （常见的有 丢弃dropna( )和填充 fillna( )）

# %% [raw]
# (1)处理缺失值一般有几种思路
#    直接赋值、丢弃、填充
# (2) 请尝试对Age列的数据的缺失值进行处理
#
# (3) 请尝试使用不同的方法直接对整张表的缺失值进行处理

# %%
df.Age.isnull().any()
# Out:
# True

# %%
#  定位缺失值所在
df[df.isnull().values == True]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 5              6         0       3                          Moran, Mr. James
# ..           ...       ...     ...                                       ...
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# 5      male   NaN      0      0            330877   8.4583   NaN        Q
# 5      male   NaN      0      0            330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [866 rows x 12 columns]

# %%
#  找出某列数据是缺失值 的整体数据
df[df.Age.isnull().values == True]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 5      male  NaN      0      0      330877   8.4583   NaN        Q
# 17     male  NaN      0      0      244373  13.0000   NaN        S
# 19   female  NaN      0      0        2649   7.2250   NaN        C
# 26     male  NaN      0      0        2631   7.2250   NaN        C
# 28   female  NaN      0      0      330959   7.8792   NaN        Q
# ..      ...  ...    ...    ...         ...      ...   ...      ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S
# 868    male  NaN      0      0      345777   9.5000   NaN        S
# 878    male  NaN      0      0      349217   7.8958   NaN        S
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S
#
# [177 rows x 12 columns]

# %%
#尝试课程例子
df[df['Age']==None]=0
df.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q

# %%
df[df['Age'].isnull()]=0   #将 Age 是缺失值的所在行数据  全都赋值为0 
df.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            0         0       0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                                  0       0   0.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0                 0   0.0000     0        0

# %%
df[df['Age'] == np.nan]=0    # 同上，  三个例子 发现  在numpy pandas中  None 和 缺失值 是不同的数据类型
df.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            0         0       0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                                  0       0   0.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0                 0   0.0000     0        0

# %% [raw]
# 【思考】检索空缺值用np.nan,None以及.isnull()哪个更好，这是为什么？如果其中某个方式无法找到缺失值，原因又是为什么？
#
# 【回答】数值列读取数据后，空缺值的数据类型为float64所以用None一般索引不到，比较的时候最好用np.nan

# %%
# 丢弃缺失值
df.dropna().head(6) # 将有缺失值的 整行数据直接丢弃,默认 inplace = False 没有修改 原数据
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 5             0         0       0
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                                                   0       0   0.0      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 5       0         0   0.0000     0        0
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
df.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            0         0       0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                                  0       0   0.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0                 0   0.0000     0        0

# %% [raw]
# df.dropna(inplace=True).head(6)   #  在原数据上操作

# %%
df.fillna(0).head(6)  #  fillna填充：将缺失值填充为 0
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            0         0       0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                                  0       0   0.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500     0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250     0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500     0        S
# 5      0                 0   0.0000     0        0

# %% [raw]
# 【思考】dropna和fillna有哪些参数，分别如何使用呢?
# 1. dropna（axis = 0 , how = 'any' , thresh = None , subset = None , inplace = False）  （默认值）
#     axis = 0 （index） 默认删除包含缺失值的行； axis = 1 （columns） 删除包含缺失值的列
#     how = 'any'，如果存在任何缺失值NA，则删除该行或列；  how = 'all'，当所有值都是NA时，则删除该行或列
#     thresh = None     int  可选，需要许多非 NA 值
#     subset = None   类似子集，数组、可选 沿其他轴的标签要考虑，例如，如果您要删除行，这些将是要包含的列表。 下面举例：
#     inplace = False  老朋友了，默认 False  不直接修改原数据；若为True，就地操作修改原数据
# 2.fillna ( value = None , method = None , axis = None , inplace = False , limit = None , downcast = None )  ---使用指定的方法填充缺失值
#     value ： 标量、字典、Series或DataFrame。用于填充空洞的值（例如 0），或者指定用于每个索引（对于系             列）或列（对于数据帧）的值的 dict/Series/DataFrame 值。不在 dict/Series/DataFrame 中的值将           不会被填充。此值不能是列表。
#     method ： 方法，有 ffill 和 bfill 用前一个或后一个有效数据进行填充 即向前或向后传播非null值，## 注            意先排序，下面举例子尝试
#     axis：填充 行或者列   axis = 0 （行 inedx） axis = 1 （列 columns）
#     limit：int 如果指定了method，则这是要向前/向后填充的连续NaN值的最大数量。换句话说，如果存在连续的          NaN数量大于此数量的缺口，它将仅被部分填充。如果未指定method，则这是将填写NaN的整个轴上的最大          条目数。如果不为None，则必须大于0。

# %%
df_e = pd.DataFrame([[np.nan, 2, np.nan, 0],
                     [3, 4, np.nan, 1],
                     [np.nan, np.nan, np.nan, 5],
                     [1, 2, 3, 4]],
                     columns=list('ABCD'))
df_e
# Out:
#      A    B    C  D
# 0  NaN  2.0  NaN  0
# 1  3.0  4.0  NaN  1
# 2  NaN  NaN  NaN  5
# 3  1.0  2.0  3.0  4

# %%
df_e.dropna()
# Out:
#      A    B    C  D
# 3  1.0  2.0  3.0  4

# %%
df_e.dropna(axis=1)
# Out:
#    D
# 0  0
# 1  1
# 2  5
# 3  4

# %%
df_e.dropna(how='all') #当某行全是NaN时，才会被删除
# Out:
#      A    B    C  D
# 0  NaN  2.0  NaN  0
# 1  3.0  4.0  NaN  1
# 2  NaN  NaN  NaN  5
# 3  1.0  2.0  3.0  4

# %%
# thresh 参数
df_e.dropna(thresh=2)  # 保留至少有 2 个 非NaN 的行
# Out:
#      A    B    C  D
# 0  NaN  2.0  NaN  0
# 1  3.0  4.0  NaN  1
# 3  1.0  2.0  3.0  4

# %%
df_e.dropna(thresh=3)
# Out:
#      A    B    C  D
# 1  3.0  4.0  NaN  1
# 3  1.0  2.0  3.0  4

# %%
df_e
# Out:
#      A    B    C  D
# 0  NaN  2.0  NaN  0
# 1  3.0  4.0  NaN  1
# 2  NaN  NaN  NaN  5
# 3  1.0  2.0  3.0  4

# %%
# subset 参数
df_e.dropna(subset=['B','D'])   # 只查看 'B'、'D'列，若有缺失值NA则drop所在行
# Out:
#      A    B    C  D
# 0  NaN  2.0  NaN  0
# 1  3.0  4.0  NaN  1
# 3  1.0  2.0  3.0  4

# %% [markdown]
# ##### fillna( ) 函数

# %%
df_e
# Out:
#      A    B    C  D
# 0  NaN  2.0  NaN  0
# 1  3.0  4.0  NaN  1
# 2  NaN  NaN  NaN  5
# 3  1.0  2.0  3.0  4

# %%
# value = None
df_e.fillna(0)  # 将缺失值 填充为 0
# Out:
#      A    B    C  D
# 0  0.0  2.0  0.0  0
# 1  3.0  4.0  0.0  1
# 2  0.0  0.0  0.0  5
# 3  1.0  2.0  3.0  4

# %%
# value = None 针对性填充  
# 将“ A”，“ B”，“ C”和“ D”列中的所有NaN元素分别替换为0、1、2和3
values = {'A':0,'B':1,'C':2,'D':3}
df_e.fillna(value=values)
# Out:
#      A    B    C  D
# 0  0.0  2.0  2.0  0
# 1  3.0  4.0  2.0  1
# 2  0.0  1.0  2.0  5
# 3  1.0  2.0  3.0  4

# %%
# method = ffill / bfill
df_e
# Out:
#      A    B    C  D
# 0  NaN  2.0  NaN  0
# 1  3.0  4.0  NaN  1
# 2  NaN  NaN  NaN  5
# 3  1.0  2.0  3.0  4

# %%
df_e.fillna(method='ffill')    # 前一个有效数值来填充缺失值  即 缺失值向前取一个有效值
# Out:
#      A    B    C  D
# 0  NaN  2.0  NaN  0
# 1  3.0  4.0  NaN  1
# 2  3.0  4.0  NaN  5
# 3  1.0  2.0  3.0  4

# %%
df_e.fillna(method='bfill') # 后一个有效值来填充缺失值，即 缺失值向后取有效值
# Out:
#      A    B    C  D
# 0  3.0  2.0  3.0  0
# 1  3.0  4.0  3.0  1
# 2  1.0  2.0  3.0  5
# 3  1.0  2.0  3.0  4

# %%
# limit 参数 
df_e
# Out:
#      A    B    C  D
# 0  NaN  2.0  NaN  0
# 1  3.0  4.0  NaN  1
# 2  NaN  NaN  NaN  5
# 3  1.0  2.0  3.0  4

# %%
# 沿 列轴 仅 替换 第1个缺失值
df_e.fillna(0,limit=1)
# Out:
#      A    B    C  D
# 0  0.0  2.0  0.0  0
# 1  3.0  4.0  NaN  1
# 2  NaN  0.0  NaN  5
# 3  1.0  2.0  3.0  4

# %%
df_e.fillna(99,limit=2)
# Out:
#       A     B     C  D
# 0  99.0   2.0  99.0  0
# 1   3.0   4.0  99.0  1
# 2  99.0  99.0   NaN  5
# 3   1.0   2.0   3.0  4

# %% [markdown]
# ### 2.2 重复值观察与处理
# ##### 2.2.1  请查看数据中的重复值

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.duplicated().head(6)  #查看是否有重复值 还有 df.duplicated(subset=[])的用法，查看某列是否有重复值
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#  举例：
df_e2 = pd.DataFrame([[1,2,3,4],
                      [1,4,5,6],
                      [1,2,3,4],
                      [1,5,6,7]],
                     columns=list('ABCD'))
df_e2    # 例子既要有 行有重复值 又要有列有重复值，便于区分
# Out:
#    A  B  C  D
# 0  1  2  3  4
# 1  1  4  5  6
# 2  1  2  3  4
# 3  1  5  6  7

# %%
df_e2.duplicated()  # 结果说明 行索引为2的是与其他重复  即行索引的数值相同的为重复值
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
df_e2[df_e2.duplicated()]   # 找出重复行！！ 所以 df.duplicated( )函数 返回的是行的重复情况
# Out:
#    A  B  C  D
# 2  1  2  3  4

# %% [markdown]
# #### 2.2.2 对重复值进行处理  （重复值指的是 行数值相同，谨记！！）
# #####  (1)重复值有哪些处理方式呢？
# #####  (2)处理我们数据的重复值

# %% [raw]
# 1)重复值有哪些处理方式呢？
# pandas提供了两个方法专门用来处理数据中的重复值，分别为duplicated()和drop_duplicates()方法。其中，前者用于标记是否有重复值，后者用于删除重复值，它们的判断标准是一样的，即只要两行数据中所有的值完全相等，就判断为重复值。

# %%
# 举例处理
df_e2
# Out:
#    A  B  C  D
# 0  1  2  3  4
# 1  1  4  5  6
# 2  1  2  3  4
# 3  1  5  6  7

# %%
df_e2.drop_duplicates()  
# drop_duplicates() 函数 发现丢弃了与之前出现过的重复值，即保留的第一个 (keep参数，默认keep = first)
# Out:
#    A  B  C  D
# 0  1  2  3  4
# 1  1  4  5  6
# 3  1  5  6  7

# %%
# drop_duplicates( ) 函数 及参数
df_e2
# Out:
#    A  B  C  D
# 0  1  2  3  4
# 1  1  4  5  6
# 2  1  2  3  4
# 3  1  5  6  7

# %%
df_e2.drop_duplicates(['B'])  # 以'B'列为基准， 根据'B'列来过滤重复值，发现 过滤了第二次出现的'2'所在行
# Out:
#    A  B  C  D
# 0  1  2  3  4
# 1  1  4  5  6
# 3  1  5  6  7

# %%
# keep 参数  first or  last  默认是 first 即保留第一次出现的重复值
df_e2
# Out:
#    A  B  C  D
# 0  1  2  3  4
# 1  1  4  5  6
# 2  1  2  3  4
# 3  1  5  6  7

# %%
df_e2.drop_duplicates(keep='first') # 默认
# Out:
#    A  B  C  D
# 0  1  2  3  4
# 1  1  4  5  6
# 3  1  5  6  7

# %%
df_e2.drop_duplicates(keep='last')
# Out:
#    A  B  C  D
# 1  1  4  5  6
# 2  1  2  3  4
# 3  1  5  6  7

# %% [markdown]
# #### 2.2.3 保存数据 --- df.to_csv('文件名')

# %% [markdown]
# ### 2.3 特征观察与处理
